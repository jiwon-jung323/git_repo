# %% [markdown]
# # 구독서비스 데이터 A/B테스트 분석

# %% [markdown]
# ## 프로젝트 개요

# %% [markdown]
# - 구독서비스 구입화면의 버전 두가지(A/B)에 대해 유의미한 차이가 있는지 검증하여 UI/UX 개선에 의사결정 근거 마련

# %% [markdown]
# ## 분석목표

# %% [markdown]
# ## 데이터

# %% [markdown]
# ## 사용 툴

# %% [markdown]
# ## 주요결과

# %% [markdown]
# ## 결론

# %% [markdown]
# ## 참고 링크
